# %% [markdown]
# ## Data Ingestion

# %%
#Document Data Structure

from langchain_core.documents import Document

# %%
doc = Document(page_content="Hey this is hydra here !!!",
               metadata={
                   "source":"google.com",
                   "page" :3,
                   "author":"Ansh",
                   "date_created" : "2026-02-05"
               })
doc
# Out:
# Document(metadata={'source': 'google.com', 'page': 3, 'author': 'Ansh', 'date_created': '2026-02-05'}, page_content='Hey this is hydra here !!!')

# %%
#create a simple txt file

import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/python_intro.txt":"""
    Python is a popular, high-level, general-purpose programming language created by Guido van Rossum in 1991.
    Why Learn PythonSimple Syntax: Reads like English, making it easy for beginners.
    Versatile: Used in web development, data science, artificial intelligence, and automation.
    Cross-Platform: Runs on Windows, Mac, and Linux.To get started quickly without installing anything, you can try running code directly in your browser using the Programiz Online Python Editor or download the official installer from the Python Official Website.
    Watch this video for a quick tutorial on Python basics and writing your first program
    Often, a program called "Hello, World!" is used to introduce a new programming language to beginners. A "Hello, World!" program is a simple program that outputs "Hello, World!" on the screen.

    Since Python has very simple syntax, creating this program can be done in a single line: print("Hello, World!"). So instead, we are going to write a different program to add two numbers as our first program.
    """
}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding='utf-8') as f:
        f.write(content)

    print("Sample text created")
# Out:
# Sample text created

# %%
#TextLoaders

from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt",encoding='utf-8')
document = loader.load() 
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='\n    Python is a popular, high-level, general-purpose programming language created by Guido van Rossum in 1991.\n    Why Learn PythonSimple Syntax: Reads like English, making it easy for beginners.\n    Versatile: Used in web development, data science, artificial intelligence, and automation.\n    Cross-Platform: Runs on Windows, Mac, and Linux.To get started quickly without installing anything, you can try running code directly in your browser using the Programiz Online Python Editor or download the official installer from the Python Official Website.\n    Watch this video for a quick tutorial on Python basics and writing your first program\n    Often, a program called "Hello, World!" is used to introduce a new programming language to beginners. A "Hello, World!" program is a simple program that outputs "Hello, World!" on the screen.\n\n    Since Python has very simple syntax, creating this program 
# ...

# %%
#Directory Loader
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", #pattern to match the files
    loader_cls=TextLoader, 
    loader_kwargs={'encoding':'utf-8'}, 
)

documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/java_introduction.txt'}, page_content='Introduction to Java\n\nJava is a general-purpose, object-oriented programming language originally developed at Sun Microsystems. It is designed around the idea of writing code once and running it on different platforms through the Java Virtual Machine (JVM).\n\nJava is strongly typed and commonly compiled into bytecode. The JVM executes this bytecode, which makes Java applications portable across operating systems that support a compatible JVM.\n\nA simple Java program:\n\npublic class Main {\n    public static void main(String[] args) {\n        System.out.println("Hello, World!");\n    }\n}\n\nJava provides automatic memory management through garbage collection. It also includes extensive standard libraries and is widely used for backend development, enterprise applications, Android-related development, distributed systems, and large-scale software.\n\nImportant Java concepts include classes, 
# ...

# %%
from langchain_community.document_loaders import PyMuPDFLoader


dir_loader = DirectoryLoader(
    "../data/pdf_files",
    glob="**/*.pdf", #pattern to match the files
    loader_cls=PyMuPDFLoader, 
)

documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-08-31T17:09:22+00:00', 'source': '../data/pdf_files/ai_era_long_31_august_2026.pdf', 'file_path': '../data/pdf_files/ai_era_long_31_august_2026.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-08-31T17:09:22+00:00', 'trapped': '', 'modDate': "D:20260831170922+00'00'", 'creationDate': "D:20260831170922+00'00'", 'page': 0}, page_content="The AI Era — Latest Developments on 31 August\n2026\nAn approximately 1,000-word explainer on how artificial intelligence is changing computing, business,\ncybersecurity, science and economic policy.\n1. AI is moving from chat to action\nThe defining change in the current AI era is the movement from systems that merely generate answers\ntoward systems that can perform tasks. Earlier generations of consumer AI were primarily inte
# ...
